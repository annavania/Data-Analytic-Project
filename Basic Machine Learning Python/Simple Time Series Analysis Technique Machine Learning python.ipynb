# %%
import pandas as pd
df = pd.read_csv(r'C:\all dataset\UMTMVS.csv', index_col='DATE')#import csv and set date as index column
df.head()
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1992-02-01  232679.0
# 1992-03-01  249673.0
# 1992-04-01  239666.0
# 1992-05-01  243231.0

# %%
df.index #check index data type to know if the index is simple objects or pandas built-in DateTime datatype.
# Out:
# Index(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01', '1992-05-01',
#        '1992-06-01', '1992-07-01', '1992-08-01', '1992-09-01', '1992-10-01',
#        ...
#        '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#        '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01', '2021-09-01'],
#       dtype='object', name='DATE', length=357)

# %%
df.index = pd.to_datetime(df.index) #convert simple object to date time
df.index
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01',
#                '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#                '2021-08-01', '2021-09-01'],
#               dtype='datetime64[ns]', name='DATE', length=357, freq=None)

# %%
df = pd.read_csv(r'C:\all dataset\UMTMVS.csv', index_col='DATE', parse_dates=True)
df.index #example of loading data in single code
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01',
#                '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#                '2021-08-01', '2021-09-01'],
#               dtype='datetime64[ns]', name='DATE', length=357, freq=None)

# %%
df.loc['2000-01-01':'2015-01-01'] #get all the data from 2000-01-01 till 2015-05-01
# Out:
#               UMTMVS
# DATE
# 2000-01-01  314656.0
# 2000-02-01  342744.0
# 2000-03-01  374859.0
# 2000-04-01  344093.0
# 2000-05-01  356402.0
# ...              ...
# 2014-09-01  513098.0
# 2014-10-01  505475.0
# 2014-11-01  458398.0
# 2014-12-01  472646.0
# 2015-01-01  424104.0
#
# [181 rows x 1 columns]

# %%
df.loc['1992-01-01':'2000-01-01':12] #the data every 12 months, from 1992 till 2000 because it's in month format
# Out:
#               UMTMVS
# DATE
# 1992-01-01  209438.0
# 1993-01-01  223258.0
# 1994-01-01  234097.0
# 1995-01-01  260175.0
# 1996-01-01  263041.0
# 1997-01-01  280870.0
# 1998-01-01  290004.0
# 1999-01-01  293222.0
# 2000-01-01  314656.0

# %%
df.resample(rule='AS').mean().head() #calculate the mean value of shipment at the start of every year by calling resample at rule='AS' for Year Start and then calling the aggregate function mean on it.
# Out:
#                    UMTMVS
# DATE
# 1992-01-01  242002.000000
# 1993-01-01  251708.083333
# 1994-01-01  269842.666667
# 1995-01-01  289973.083333
# 1996-01-01  299765.666667

# %%
df.rolling(window=10).mean().head(20) # head to see first 20 values
# Out:
#               UMTMVS
# DATE
# 1992-01-01       NaN
# 1992-02-01       NaN
# 1992-03-01       NaN
# 1992-04-01       NaN
# 1992-05-01       NaN
# 1992-06-01       NaN
# 1992-07-01       NaN
# 1992-08-01       NaN
# 1992-09-01       NaN
# 1992-10-01  241316.0
# 1992-11-01  244898.3
# 1992-12-01  246190.7
# 1993-01-01  243549.2
# 1993-02-01  244276.7
# 1993-03-01  246442.2
# 1993-04-01  245074.9
# 1993-05-01  247878.7
# 1993-06-01  250953.5
# 1993-07-01  247339.6
# 1993-08-01  247008.7

# %%
df.rolling(window=30).max()[30:].head(20) # heck out the maximum value from a window of 30 days
# Out:
#               UMTMVS
# DATE
# 1994-07-01  287336.0
# 1994-08-01  287336.0
# 1994-09-01  291357.0
# 1994-10-01  291357.0
# 1994-11-01  291357.0
# 1994-12-01  291357.0
# 1995-01-01  291357.0
# 1995-02-01  291357.0
# 1995-03-01  303201.0
# 1995-04-01  303201.0
# 1995-05-01  303201.0
# 1995-06-01  310201.0
# 1995-07-01  310201.0
# 1995-08-01  310201.0
# 1995-09-01  313228.0
# 1995-10-01  313228.0
# 1995-11-01  313228.0
# 1995-12-01  313228.0
# 1996-01-01  313228.0
# 1996-02-01  313228.0

# %%
df.plot()#basic line plot
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
ax = df.plot()
ax.set(title='Value of Manufacturers Shipments', ylabel='Value') #adding title and y label
# Out:
# [Text(0.5, 1.0, 'Value of Manufacturers Shipments'), Text(0, 0.5, 'Value')]

# %%
ax = df.plot(figsize=(12,6))
ax.set(title='Value of Manufacturers Shipments', ylabel='Value') # change the plot size via figsize parameter in .plot.
# Out:
# [Text(0.5, 1.0, 'Value of Manufacturers Shipments'), Text(0, 0.5, 'Value')]

# %%
ax = df.resample(rule='AS').mean().plot(figsize=(12,6))
ax.set(title='Average of Manufacturers Shipments', ylabel='Value of Mean of Starting of Year')
#Plot the mean of the starting value of every year via calling .plot after resampling with the rule ‘AS’ as ‘AS’ is the rule for the starting of the year.
# Out:
# [Text(0.5, 1.0, 'Average of Manufacturers Shipments'),
#  Text(0, 0.5, 'Value of Mean of Starting of Year')]

# %%
ax = df.resample(rule='AS').mean().plot.bar(figsize=(12,6))
ax.set(title='Average of Manufacturers Shipments', ylabel='Value of Mean of Starting of Year');
#bar plot for the mean of starting of every year by calling .bar on top of .plot.

# %%
ax = df['UMTMVS'].resample(rule='MS').mean().plot(figsize=(15,8), label='Resample MS')
ax.autoscale(tight=True)
df.rolling(window=30).mean()['UMTMVS'].plot(label='Rolling window=30')

ax.set(ylabel='Value of Mean of Starting of Month',title='Average of Manufacturers Shipments')
ax.legend()

#plot the rolling mean and normal mean for the starting of the month

# %%
ax = df['UMTMVS'].resample(rule='AS').max().plot(xlim=["1999-01-01","2014-01-01"],ylim=[280000,540000], figsize=(12,7))
ax.yaxis.grid(True)
ax.xaxis.grid(True)

#plot the maximum values for the start of every year from 1995 till 2014.
